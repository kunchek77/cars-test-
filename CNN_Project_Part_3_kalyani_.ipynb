# %% [markdown]
# <a href="https://colab.research.google.com/github/kunchek77/cars-test-/blob/main/CNN_Project_Part_3_kalyani_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# DOMAIN: Automobile
#
# • CONTEXT: A brand research company wants to understand which cars or car manufacturers are popular in a
# certain area of the city or locality. Company has a team which takes pictures of the cars randomly through the day. Using this the company wants to set up an automation which can classify the make of the car once the picture has been given as an input.
#
# • TASK: Help to build the image dataset to be used by the AI team to build an image classifier data. Import and display the images in python against their labels. Comment on the challenges faced during this task.

# %% [markdown]
# - Import images in python

# %%
from skimage.io import imread_collection

#your path 
col_dir = '/content/*.jpg'


#creating a collection with the available images
col = imread_collection(col_dir)

# %% [markdown]
# - Display images in python

# %%
# visualizing the first 10 images in the dataset and their labels

# VISUALIZATION
import matplotlib.pyplot as plt # MATPLOTLIB FOR PLOTTING
import seaborn as sns

N=15  # NUMBER OF IMAGES YOU WISH TO SEE

plt.figure(figsize=(N, 1))
for i in range(N):
    plt.subplot(1, N, i+1)
    plt.imshow(col[i], cmap="gray")  # greens, reds, blues, rgb
    plt.axis('off')
plt.show()

# %% [markdown]
# - Tag annotations separately on an excel file [ GP: 1 point ]
#
# Manual task to be done on a excel, csv, txt or json file outside python environment

# %% [markdown]
# - Import annotations in python [ GP: 1 point ]

# %%
import pandas as pd

Annotations=pd.read_excel("/content/Part-3 Cars_Annotations - output expected to be created manually.xlsx")
Annotations.head()
# Out:
#    No.     Image     Color     Make
# 0    1  00001.jpg    White     Audi
# 1    2  00002.jpg  Black.     Acura
# 2    3  00003.jpg      Red    Dodge
# 3    4  00004.jpg      Red  Hyundai
# 4    5  00005.jpg    White     Ford

# %% [markdown]
# - Display annothation in python [ GP: 1 point ]

# %%
Label_Color=Annotations['Color']
Label_Color
# Out:
# 0       White
# 1     Black.
# 2         Red
# 3         Red
# 4       White
# 5         Red
# 6        Blue
# 7         Red
# 8        Gray
# 9      Silver
# 10      White
# 11       Gray
# 12     White
# 13      White
# 14        Red
# Name: Color, dtype: object

# %%
Label_Make=Annotations['Make']
Label_Make
# Out:
# 0           Audi
# 1          Acura
# 2          Dodge
# 3        Hyundai
# 4           Ford
# 5        Unknown
# 6          Dodge
# 7          Dodge
# 8     Mitsubishi
# 9      Chevrolet
# 10       Unknown
# 11        Toyota
# 12       Hyundai
# 13       Unknown
# 14         Volvo
# Name: Make, dtype: object

# %% [markdown]
# - Display images vs Annotation in python

# %%
# visualizing the first 10 images in the dataset and their labels

# VISUALIZATION
import matplotlib.pyplot as plt # MATPLOTLIB FOR PLOTTING
import seaborn as sns

N=15  # NUMBER OF IMAGES YOU WISH TO SEE

plt.figure(figsize=(N, 1))
for i in range(N):
    plt.subplot(1, N, i+1)
    plt.imshow(col[i], cmap="gray")  # greens, reds, blues, rgb
    plt.title("{}".format(Label_Make[i]))
    plt.axis('off')
plt.show()

# %%
# visualizing the first 10 images in the dataset and their labels

# VISUALIZATION
import matplotlib.pyplot as plt # MATPLOTLIB FOR PLOTTING
import seaborn as sns

N=15  # NUMBER OF IMAGES YOU WISH TO SEE

plt.figure(figsize=(N, 1))
for i in range(N):
    plt.subplot(1, N, i+1)
    plt.imshow(col[i], cmap="gray")  # greens, reds, blues, rgb
    plt.title("{}".format(Label_Color[i]))
    plt.axis('off')
plt.show()

# %% [markdown]
# - Learnings or challenges faced

# %% [markdown]
# As Manual tagging is challenging and time consuming when the voulume of the data is huge so its best to bring  automation to do the same.
